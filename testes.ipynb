# %%
import pandas as pd
import streamlit as st
import plotly.express as px

# %%
df = pd.read_csv('dados\\focos_diario_br_20251125.csv')
df.head()
# Out:
#                                      id       lat       lon  \
# 0  083b67de-79f6-37bd-bc28-20ea719516fc -21.57989 -56.47596
# 1  29150544-a756-387a-98f0-87f91dfa4b6d -19.33016 -54.34638
# 2  95cb83ed-8cd6-30d5-bc78-4294aad85d75 -21.70672 -57.66293
# 3  bf9b860a-256e-352f-baf2-13607644ceaa -18.57343 -53.46037
# 4  6abe7a58-cc7c-3810-81b9-da6db663e8c2 -18.11726 -54.51959
#
#          data_hora_gmt   satelite             municipio              estado  \
# 0  2025-11-25 01:09:00  TERRA_M-M                JARDIM  MATO GROSSO DO SUL
# 1  2025-11-25 01:09:00  TERRA_M-M  SÃO GABRIEL DO OESTE  MATO GROSSO DO SUL
# 2  2025-11-25 01:09:00  TERRA_M-M        PORTO MURTINHO  MATO GROSSO DO SUL
# 3  2025-11-25 01:09:00  TERRA_M-M            COSTA RICA  MATO GROSSO DO SUL
# 4  2025-11-25 01:09:00  TERRA_M-M           PEDRO GOMES  MATO GROSSO DO SUL
#
#      pais  municipio_id  estado_id  pais_id  numero_dias_sem_chuva  \
# 0  Brasil       5005004         50       33                      2
# ...

# %%
df_amapa = df[df['estado'] == 'AMAPÁ']
df_amapa.head()
# Out:
#                                        id      lat       lon  \
# 962  90f6ec99-a5d3-389b-9f94-38c2ea47ebba  1.70984 -50.74757
# 963  fb251781-99d4-3a90-820f-cfdc3148ad8a  1.70202 -50.74457
# 964  82055dff-1524-3e8f-8e63-4cae2e388bc5  1.70689 -50.75224
# 965  f59e1e12-a581-3187-bbe5-dd8e7ba61d0e  1.70625 -50.74812
# 982  eec7a003-427c-3275-b453-304bd6c55816  1.35864 -50.67700
#
#            data_hora_gmt satelite        municipio estado    pais  \
# 962  2025-11-25 04:36:00  NOAA-20         PRACUÚBA  AMAPÁ  Brasil
# 963  2025-11-25 04:36:00  NOAA-20         PRACUÚBA  AMAPÁ  Brasil
# 964  2025-11-25 04:36:00  NOAA-20         PRACUÚBA  AMAPÁ  Brasil
# 965  2025-11-25 04:36:00  NOAA-20         PRACUÚBA  AMAPÁ  Brasil
# 982  2025-11-25 04:38:00  NOAA-20  TARTARUGALZINHO  AMAPÁ  Brasil
#
#      municipio_id  estado_id  pais_id  numero_dias_sem_chuva  precipitacao  \
# 962       1600550         16       33                      3           0.0
# ...

# %%
df_amapa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 229 entries, 962 to 9442
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     229 non-null    object
#  1   lat                    229 non-null    float64
#  2   lon                    229 non-null    float64
#  3   data_hora_gmt          229 non-null    object
#  4   satelite               229 non-null    object
#  5   municipio              229 non-null    object
#  6   estado                 229 non-null    object
#  7   pais                   229 non-null    object
#  8   municipio_id           229 non-null    int64
#  9   estado_id              229 non-null    int64
#  10  pais_id                229 non-null    int64
#  11  numero_dias_sem_chuva  229 non-null    int64
#  12  precipitacao           229 non-null    float64
#  13  risco_fogo             229 non-null    float64
# ...
